# %%
# BASIC - Batch Normalization

# %%
import tensorflow as tf
import numpy as np
import time
import os
import matplotlib.pyplot as plt

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dicts = pickle.load(fo, encoding='bytes')
    return dicts

# %%
ROW, COL = 32, 32
DEPTH = 3
trX = np.array([]).reshape([0, ROW*COL*DEPTH])
trY = np.array([])
for i in range(5):
    dicts = unpickle('./cifar10/data_batch_{}'.format(i+1))
    trX = np.concatenate((trX, dicts[b'data'])).astype(np.float32)
    trY = np.concatenate((trY, dicts[b'labels'])).astype(np.int64)
trX = np.reshape(trX, [len(trX), DEPTH, ROW, COL]).transpose([0, 2, 3, 1])

dicts = unpickle('./cifar10/test_batch')
teX = dicts[b'data'].astype(np.float32)
teY = np.array(dicts[b'labels'], dtype=np.int64)
teX = np.reshape(teX, [len(teX), DEPTH, ROW, COL]).transpose([0, 2, 3, 1])
trX /= 255
teX /= 255

# %%
want_num = 4
fig, ax = plt.subplots(nrows=want_num, ncols=want_num, figsize = (10, 10))
check = 2200
for i in range(want_num):
    for j in range(want_num):
        ax[i][j].imshow(trX[want_num*i+j + check])

    print(trY[want_num*i + check : want_num*(i+1) + check])
        
plt.show()
# Out:
# [1 7 2 6]
# [1 2 9 7]
# [9 0 4 7]
# [8 4 9 9]

# %%
want_num = 4
fig, ax = plt.subplots(nrows=want_num, ncols=want_num, figsize = (10, 10))
check = 2200
for i in range(want_num):
    for j in range(want_num):
        ax[i][j].imshow(teX[want_num*i+j + check])

    print(teY[want_num*i + check : want_num*(i+1) + check])
        
plt.show()
# Out:
# [0 5 9 6]
# [9 5 1 3]
# [4 4 2 7]
# [2 4 4 0]

# %%
def batch_norm(inputs, momentum=0.9, epsilon=1e-5, scale=True, is_training=True, name='batch_norm'):
    return tf.contrib.layers.batch_norm(inputs=inputs, decay=momentum, 
                                        epsilon=epsilon, scale=scale, 
                                        is_training=is_training, 
                                        updates_collections=None, scope=name)

def conv2d(inputs, filters, k_size, reg=False, padding='same', activation=None, strides=1, name='conv'):
    if reg:
        return tf.layers.conv2d(inputs=inputs, filters=filters, kernel_size=k_size, 
                                kernel_regularizer=tf.contrib.layers.l2_regularizer(0.01),
                                strides=strides, padding=padding, 
                                activation=activation, name=name)
    else:
        return tf.layers.conv2d(inputs=inputs, filters=filters, kernel_size=k_size, 
                                strides=strides, padding=padding, 
                                activation=activation, name=name)
    
def maxpool(inputs, k_size=2, padding='same', strides=2, name='pooling'):
    return tf.layers.max_pooling2d(inputs=inputs, pool_size=k_size, 
                                   padding=padding, strides=strides, name=name)

# %%
def block(inputs, filters, training=True, block_num=0, is_bn=True):
    if is_bn:
        h = conv2d(inputs, filters=filters, k_size=3, activation=None, name='h{}'.format(block_num))
        h_bn = batch_norm(h, is_training=training, name='h{}_bn'.format(block_num))
        h_act = tf.nn.relu(h_bn, name='h{}_act'.format(block_num))
        m = maxpool(h_act, name='h{}_pool'.format(block_num))
    else:
        h = conv2d(inputs, filters=filters, k_size=3, activation=tf.nn.relu, name='h{}'.format(block_num))
        m = maxpool(h, name='h{}_pool'.format(block_num))
    return m

# %%
def get_accuracy(sess, logits, img, label, batch_size):    
    if len(img) < batch_size:
        logit = sess.run(logits, feed_dict={X: img, training: False})
    else:
        total_batch = np.ceil((len(img) / batch_size)).astype(np.int32)
        num_classes = int(logits.shape[-1])
        logit = np.array([], dtype=np.int64).reshape(0, num_classes)
        idxs = range(len(img))
        for i in range(total_batch):
            idxs_i = idxs[i * batch_size : (i + 1) * batch_size]
            feed_dict = {X: img[idxs_i], training: False}
            logit = np.concatenate((logit, sess.run(logits, feed_dict=feed_dict)), axis=0)

    correct_pred = np.equal(np.argmax(logit, 1), label).astype(np.float32)
    accuracy = np.mean(correct_pred)
    
    return accuracy, logit, correct_pred

# %%
MODEL = 'baseline'

X = tf.placeholder(tf.float32, [None, ROW, COL, DEPTH], name='input')
Y = tf.placeholder(tf.int64, [None], name='label')
training = tf.placeholder(tf.bool, name='is_training')


bl0 = block(inputs=X, filters=32, training=training, block_num=0, is_bn=False)
bl1 = block(inputs=bl0, filters=64, training=training, block_num=1, is_bn=False)
bl2 = block(inputs=bl1, filters=128, training=training, block_num=2, is_bn=False)
bl3 = block(inputs=bl2, filters=256, training=training, block_num=3, is_bn=False)

output = bl3

flat = tf.reshape(output, [-1, int(np.prod(output.shape[1:]))])
dense1 = tf.layers.dense(flat, units=128, activation=tf.nn.relu, name='dense1')
logits = tf.layers.dense(dense1, units=10, activation=None, name='dense2')

# %%
MODEL = 'batch_normal'

X = tf.placeholder(tf.float32, [None, ROW, COL, DEPTH], name='input')
Y = tf.placeholder(tf.int64, [None], name='label')
training = tf.placeholder(tf.bool, name='is_training')


bl0 = block(inputs=X, filters=32, training=training, block_num=0)
bl1 = block(inputs=bl0, filters=64, training=training, block_num=1)
bl2 = block(inputs=bl1, filters=128, training=training, block_num=2)
bl3 = block(inputs=bl2, filters=256, training=training, block_num=3)

output = bl3

flat = tf.reshape(output, [-1, int(np.prod(output.shape[1:]))])
dense1 = tf.layers.dense(flat, units=128, activation=None, name='dense1')
dense1_bn = batch_norm(dense1, is_training=training, name='dense1_bn')
act1 = tf.nn.relu(dense1_bn, name='dense1_act')
logits = tf.layers.dense(act1, units=10, activation=None, name='dense2')
# Out:
# C:\Users\Hyoje\Anaconda3\envs\tfgpu\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
output
# Out:
# <tf.Tensor 'h3_pool/MaxPool:0' shape=(?, 2, 2, 256) dtype=float32>

# %%
tf.trainable_variables()
# Out:
# [<tf.Variable 'h0/kernel:0' shape=(3, 3, 3, 32) dtype=float32_ref>,
#  <tf.Variable 'h0/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'h1/kernel:0' shape=(3, 3, 32, 64) dtype=float32_ref>,
#  <tf.Variable 'h1/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'h2/kernel:0' shape=(3, 3, 64, 128) dtype=float32_ref>,
#  <tf.Variable 'h2/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'h3/kernel:0' shape=(3, 3, 128, 256) dtype=float32_ref>,
#  <tf.Variable 'h3/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'dense1/kernel:0' shape=(1024, 128) dtype=float32_ref>,
#  <tf.Variable 'dense1/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'dense2/kernel:0' shape=(128, 10) dtype=float32_ref>,
#  <tf.Variable 'dense2/bias:0' shape=(10,) dtype=float32_ref>]

# %%
cost = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=0.001).minimize(cost)

# %%
# hyper prameter
BATCH_SIZE = 128
EPOCHS = 100
CHECK_POINT_DIR = './save_{}'.format(MODEL)
IS_SAVE = False

# %%
config=tf.ConfigProto(allow_soft_placement=True)
#config.gpu_options.allocator_type='BFC'
config.log_device_placement=False
config.gpu_options.allow_growth=True
#config.gpu_options.per_process_gpu_memory_fraction = 0.4

sess = tf.Session(config=config)
sess.run(tf.global_variables_initializer())

# %%
# Restore and Save
if IS_SAVE:
    saver = tf.train.Saver()
    checkpoint = tf.train.get_checkpoint_state(CHECK_POINT_DIR)

    if checkpoint and checkpoint.model_checkpoint_path:
        try:
            saver.restore(sess, checkpoint.model_checkpoint_path)
            print("Successfully loaded:", checkpoint.model_checkpoint_path)
        except:
            print("Error on loading old network weights")
    else:
        print("Could not find old network weights")
else:
    print('Do not save')
# Out:
# Do not save

# %%
# train - base line

print(time.asctime())
print('Batch size : {}, Epochs : {}, Save_dir : {}'.format(BATCH_SIZE, EPOCHS, CHECK_POINT_DIR))
print('Learning Started.')

total_start = time.time()
max_accuracy = 0.0
for epoch in range(EPOCHS):
    epoch_start = time.time()
    avg_cost = 0
    total_batch = np.ceil(trX.shape[0] / BATCH_SIZE).astype(np.int32)
    
    idxs = np.random.permutation(range(len(trX)))
    for i in range(total_batch):
        idxs_i = idxs[i * BATCH_SIZE : (i + 1) * BATCH_SIZE]
        feed_dict = {X: trX[idxs_i], Y: trY[idxs_i], training: True }    
        c, _ = sess.run([cost, optimizer], feed_dict=feed_dict)
        avg_cost += c / total_batch
    print('=====================================')
    print('Epoch : {:02d} , Cost : {:.5f}'.format(epoch + 1, avg_cost))
    train_accuracy, _, _ = get_accuracy(sess, logits, trX, trY, BATCH_SIZE)
    print('Train Accuracy : {:.5f}'.format(train_accuracy))
    test_accuracy, _, _ = get_accuracy(sess, logits, teX, teY, BATCH_SIZE)
    print('Test Accuracy : {:.5f}'.format(test_accuracy))
    print('Elapsed time of an epoch: {:.5f}'.format(time.time() - epoch_start))
    if test_accuracy > max_accuracy:
        max_accuracy = test_accuracy
        print('===========Best accuracy=============')
        print(time.asctime())
        print('Best Accuracy : {:.5f}'.format(max_accuracy))
        print('Elapsed time to get the best accuracy: {:.5f}'.format(time.time() - total_start))
        if IS_SAVE:
            print('===========Saving network with the best accuracy===========')
            if not os.path.exists(CHECK_POINT_DIR):
                os.makedirs(CHECK_POINT_DIR)
            saver.save(sess, CHECK_POINT_DIR + "/model", global_step=epoch+1)

print('=====================================')

print('Final Test Accuracy : {:.5f}'.format(max_accuracy))
print('Total elapsed time: {:.5f}'.format(time.time() - total_start))
# Out:
# Mon May 21 20:44:07 2018
# Batch size : 128, Epochs : 100, Save_dir : ./save_baseline
# Learning Started.
# =====================================
# Epoch : 01 , Cost : 1.53200
# Train Accuracy : 0.56416
# Test Accuracy : 0.55960
# Elapsed time of an epoch: 14.59083
# ===========Best accuracy=============
# Mon May 21 20:44:21 2018
# Best Accuracy : 0.55960
# Elapsed time to get the best accuracy: 14.59183
# =====================================
# Epoch : 02 , Cost : 1.09332
# Train Accuracy : 0.67774
# Test Accuracy : 0.65620
# Elapsed time of an epoch: 13.60119
# ===========Best accuracy=============
# Mon May 21 20:44:35 2018
# Best Accuracy : 0.65620
# Elapsed time to get the best accuracy: 28.19302
# =====================================
# Epoch : 03 , Cost : 0.88989
# Train Accuracy : 0.73086
# Test Accuracy : 0.68920
# Elapsed time of an epoch: 13.72051
# ===========Best accuracy=============
# Mon May 21 20:44:49 2018
# Best Accuracy : 0.68920
# Elapsed time to get the best accuracy: 41.91354
# =====================================
# Epoch : 04 , Cost : 0.74934
# Train Accuracy : 0.78930
# Test Accuracy : 0.73120
# Elapsed time of an epoch: 13.71349
# ===========Best accuracy=============
# Mon May 21 20:45:02 2018
# Best Accuracy : 0.73120
# Elapsed time to get the best accuracy: 55.62703
# =====================================
# Epoch : 05 , Cost : 0.64726
# Train Accuracy : 0.80028
# Test Accuracy : 0.72760
# Elapsed time of an epoch: 13.51396
# =====================================
# Epoch : 06 , Cost : 0.56216
# Train Accuracy : 0.84300
# Test Accuracy : 0.73270
# Elapsed time of an epoch: 13.54705
# ===========Best accuracy=============
# Mon May 21 20:45:29 2018
# Best Accuracy : 0.73270
# Elapsed time to get the best accuracy: 82.68804
# =====================================
# Epoch : 07 , Cost : 0.46581
# Train Accuracy : 0.88148
# Test Accuracy : 0.75240
# Elapsed time of an epoch: 13.66837
# ===========Best accuracy=============
# Mon May 21 20:45:43 2018
# Best Accuracy : 0.75240
# Elapsed time to get the best accuracy: 96.35641
# =====================================
# Epoch : 08 , Cost : 0.39837
# Train Accuracy : 0.90530
# Test Accuracy : 0.75280
# Elapsed time of an epoch: 13.77265
# ===========Best accuracy=============
# Mon May 21 20:45:57 2018
# Best Accuracy : 0.75280
# Elapsed time to get the best accuracy: 110.12906
# =====================================
# Epoch : 09 , Cost : 0.31719
# Train Accuracy : 0.92502
# Test Accuracy : 0.75090
# Elapsed time of an epoch: 13.71249
# =====================================
# Epoch : 10 , Cost : 0.26106
# Train Accuracy : 0.93610
# Test Accuracy : 0.74800
# Elapsed time of an epoch: 13.75089
# =====================================
# Epoch : 11 , Cost : 0.19683
# Train Accuracy : 0.95140
# Test Accuracy : 0.74480
# Elapsed time of an epoch: 23.90963
# =====================================
# Epoch : 12 , Cost : 0.16689
# Train Accuracy : 0.96190
# Test Accuracy : 0.74570
# Elapsed time of an epoch: 21.89727
# =====================================
# Epoch : 13 , Cost : 0.13471
# Train Accuracy : 0.96442
# Test Accuracy : 0.73610
# Elapsed time of an epoch: 22.01859
# =====================================
# Epoch : 14 , Cost : 0.12393
# Train Accuracy : 0.96860
# Test Accuracy : 0.74460
# Elapsed time of an epoch: 22.32775
# =====================================
# Epoch : 15 , Cost : 0.10420
# Train Accuracy : 0.97274
# Test Accuracy : 0.74830
# Elapsed time of an epoch: 22.72547
# =====================================
# Epoch : 16 , Cost : 0.09569
# Train Accuracy : 0.97244
# Test Accuracy : 0.74570
# Elapsed time of an epoch: 22.09580
# =====================================
# Epoch : 17 , Cost : 0.09208
# Train Accuracy : 0.97938
# Test Accuracy : 0.74460
# Elapsed time of an epoch: 22.28896
# =====================================
# Epoch : 18 , Cost : 0.09054
# Train Accuracy : 0.94976
# Test Accuracy : 0.72150
# Elapsed time of an epoch: 22.30045
# =====================================
# Epoch : 19 , Cost : 0.08077
# Train Accuracy : 0.98064
# Test Accuracy : 0.73540
# Elapsed time of an epoch: 22.11886
# =====================================
# Epoch : 20 , Cost : 0.06718
# Train Accuracy : 0.97920
# Test Accuracy : 0.74270
# Elapsed time of an epoch: 21.91031
# =====================================
# Epoch : 21 , Cost : 0.07545
# Train Accuracy : 0.97388
# Test Accuracy : 0.74210
# Elapsed time of an epoch: 21.94640
# =====================================
# Epoch : 22 , Cost : 0.08077
# Train Accuracy : 0.98660
# Test Accuracy : 0.74410
# Elapsed time of an epoch: 21.96345
# =====================================
# Epoch : 23 , Cost : 0.07363
# Train Accuracy : 0.97462
# Test Accuracy : 0.73600
# Elapsed time of an epoch: 21.91833
# =====================================
# Epoch : 24 , Cost : 0.06870
# Train Accuracy : 0.97534
# Test Accuracy : 0.73540
# Elapsed time of an epoch: 21.82407
# =====================================
# Epoch : 25 , Cost : 0.06925
# Train Accuracy : 0.97610
# Test Accuracy : 0.73450
# Elapsed time of an epoch: 24.07908
# =====================================
# Epoch : 26 , Cost : 0.06289
# Train Accuracy : 0.98298
# Test Accuracy : 0.73690
# Elapsed time of an epoch: 22.03163
# =====================================
# Epoch : 27 , Cost : 0.06720
# Train Accuracy : 0.98412
# Test Accuracy : 0.73460
# Elapsed time of an epoch: 21.77394
# =====================================
# Epoch : 28 , Cost : 0.05324
# Train Accuracy : 0.98276
# Test Accuracy : 0.73720
# Elapsed time of an epoch: 22.07172
# =====================================
# Epoch : 29 , Cost : 0.06384
# Train Accuracy : 0.98510
# Test Accuracy : 0.73860
# Elapsed time of an epoch: 22.09585
# =====================================
# Epoch : 30 , Cost : 0.06948
# Train Accuracy : 0.98420
# Test Accuracy : 0.74520
# Elapsed time of an epoch: 22.07846
# =====================================
# Epoch : 31 , Cost : 0.05176
# Train Accuracy : 0.99126
# Test Accuracy : 0.74090
# Elapsed time of an epoch: 22.21329
# =====================================
# Epoch : 32 , Cost : 0.05710
# Train Accuracy : 0.98778
# Test Accuracy : 0.74350
# Elapsed time of an epoch: 22.03564
# =====================================
# Epoch : 33 , Cost : 0.05547
# Train Accuracy : 0.98184
# Test Accuracy : 0.73530
# Elapsed time of an epoch: 21.89125
# =====================================
# Epoch : 34 , Cost : 0.05302
# Train Accuracy : 0.97920
# Test Accuracy : 0.74080
# Elapsed time of an epoch: 21.86518
# =====================================
# Epoch : 35 , Cost : 0.05976
# Train Accuracy : 0.98684
# Test Accuracy : 0.74380
# Elapsed time of an epoch: 21.91331
# =====================================
# Epoch : 36 , Cost : 0.04677
# Train Accuracy : 0.99044
# Test Accuracy : 0.74060
# Elapsed time of an epoch: 22.14274
# =====================================
# Epoch : 37 , Cost : 0.04388
# Train Accuracy : 0.98460
# Test Accuracy : 0.73750
# Elapsed time of an epoch: 21.86418
# =====================================
# Epoch : 38 , Cost : 0.04037
# Train Accuracy : 0.98700
# Test Accuracy : 0.73920
# Elapsed time of an epoch: 22.39252
# =====================================
# Epoch : 39 , Cost : 0.06000
# Train Accuracy : 0.98290
# Test Accuracy : 0.73720
# Elapsed time of an epoch: 24.29172
# =====================================
# Epoch : 40 , Cost : 0.04710
# Train Accuracy : 0.98814
# Test Accuracy : 0.74370
# Elapsed time of an epoch: 21.74830
# =====================================
# Epoch : 41 , Cost : 0.04252
# Train Accuracy : 0.98502
# Test Accuracy : 0.73640
# Elapsed time of an epoch: 21.85512
# =====================================
# Epoch : 42 , Cost : 0.05256
# Train Accuracy : 0.98274
# Test Accuracy : 0.73700
# Elapsed time of an epoch: 21.87421
# =====================================
# Epoch : 43 , Cost : 0.04144
# Train Accuracy : 0.99024
# Test Accuracy : 0.74560
# Elapsed time of an epoch: 21.89928
# =====================================
# Epoch : 44 , Cost : 0.04772
# Train Accuracy : 0.98872
# Test Accuracy : 0.73550
# Elapsed time of an epoch: 21.99278
# =====================================
# Epoch : 45 , Cost : 0.04651
# Train Accuracy : 0.99118
# Test Accuracy : 0.74050
# Elapsed time of an epoch: 21.98106
# =====================================
# Epoch : 46 , Cost : 0.04488
# Train Accuracy : 0.98846
# Test Accuracy : 0.74330
# Elapsed time of an epoch: 21.90529
# =====================================
# Epoch : 47 , Cost : 0.03639
# Train Accuracy : 0.98808
# Test Accuracy : 0.74190
# Elapsed time of an epoch: 21.71579
# =====================================
# Epoch : 48 , Cost : 0.05278
# Train Accuracy : 0.98558
# Test Accuracy : 0.73700
# Elapsed time of an epoch: 21.73179
# =====================================
# Epoch : 49 , Cost : 0.03718
# Train Accuracy : 0.98902
# Test Accuracy : 0.74220
# Elapsed time of an epoch: 21.77795
# =====================================
# Epoch : 50 , Cost : 0.04504
# Train Accuracy : 0.99136
# Test Accuracy : 0.74370
# Elapsed time of an epoch: 21.87009
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-dd1333ac2adb> in <module>()
#      16         idxs_i = idxs[i * BATCH_SIZE : (i + 1) * BATCH_SIZE]
#      17         feed_dict = {X: trX[idxs_i], Y: trY[idxs_i], training: True }
# ---> 18         c, _ = sess.run([cost, optimizer], feed_dict=feed_dict)
#      19         avg_cost += c / total_batch
#      20     print('=====================================')
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
print('Final Test Accuracy : {:.5f}'.format(max_accuracy))
# Out:
# Final Test Accuracy : 0.75280

# %%
# train - batch normalization

print(time.asctime())
print('Batch size : {}, Epochs : {}, Save_dir : {}'.format(BATCH_SIZE, EPOCHS, CHECK_POINT_DIR))
print('Learning Started.')

total_start = time.time()
max_accuracy = 0.0
for epoch in range(EPOCHS):
    epoch_start = time.time()
    avg_cost = 0
    total_batch = np.ceil(trX.shape[0] / BATCH_SIZE).astype(np.int32)
    
    idxs = np.random.permutation(range(len(trX)))
    for i in range(total_batch):
        idxs_i = idxs[i * BATCH_SIZE : (i + 1) * BATCH_SIZE]
        feed_dict = {X: trX[idxs_i], Y: trY[idxs_i], training: True }    
        c, _ = sess.run([cost, optimizer], feed_dict=feed_dict)
        avg_cost += c / total_batch
    print('=====================================')
    print('Epoch : {:02d} , Cost : {:.5f}'.format(epoch + 1, avg_cost))
    train_accuracy, _, _ = get_accuracy(sess, logits, trX, trY, BATCH_SIZE)
    print('Train Accuracy : {:.5f}'.format(train_accuracy))
    test_accuracy, _, _ = get_accuracy(sess, logits, teX, teY, BATCH_SIZE)
    print('Test Accuracy : {:.5f}'.format(test_accuracy))
    print('Elapsed time of an epoch: {:.5f}'.format(time.time() - epoch_start))
    if test_accuracy > max_accuracy:
        max_accuracy = test_accuracy
        print('===========Best accuracy=============')
        print(time.asctime())
        print('Best Accuracy : {:.5f}'.format(max_accuracy))
        print('Elapsed time to get the best accuracy: {:.5f}'.format(time.time() - total_start))
        if IS_SAVE:
            print('===========Saving network with the best accuracy===========')
            if not os.path.exists(CHECK_POINT_DIR):
                os.makedirs(CHECK_POINT_DIR)
            saver.save(sess, CHECK_POINT_DIR + "/model", global_step=epoch+1)

print('=====================================')

print('Final Test Accuracy : {:.5f}'.format(max_accuracy))
print('Total elapsed time: {:.5f}'.format(time.time() - total_start))
# Out:
# Mon May 21 20:26:43 2018
# Batch size : 128, Epochs : 100, Save_dir : ./save_over90
# Learning Started.
# =====================================
# Epoch : 01 , Cost : 1.11069
# Train Accuracy : 0.69696
# Test Accuracy : 0.66800
# Elapsed time of an epoch: 35.61177
# ===========Best accuracy=============
# Mon May 21 20:27:18 2018
# Best Accuracy : 0.66800
# Elapsed time to get the best accuracy: 35.61177
# =====================================
# Epoch : 02 , Cost : 0.75131
# Train Accuracy : 0.74358
# Test Accuracy : 0.69520
# Elapsed time of an epoch: 36.10006
# ===========Best accuracy=============
# Mon May 21 20:27:54 2018
# Best Accuracy : 0.69520
# Elapsed time to get the best accuracy: 71.71183
# =====================================
# Epoch : 03 , Cost : 0.58630
# Train Accuracy : 0.84726
# Test Accuracy : 0.76160
# Elapsed time of an epoch: 36.05294
# ===========Best accuracy=============
# Mon May 21 20:28:30 2018
# Best Accuracy : 0.76160
# Elapsed time to get the best accuracy: 107.76477
# =====================================
# Epoch : 04 , Cost : 0.47542
# Train Accuracy : 0.85802
# Test Accuracy : 0.74960
# Elapsed time of an epoch: 36.64102
# =====================================
# Epoch : 05 , Cost : 0.37493
# Train Accuracy : 0.87296
# Test Accuracy : 0.74570
# Elapsed time of an epoch: 36.26635
# =====================================
# Epoch : 06 , Cost : 0.28860
# Train Accuracy : 0.87244
# Test Accuracy : 0.72160
# Elapsed time of an epoch: 36.24216
# =====================================
# Epoch : 07 , Cost : 0.22150
# Train Accuracy : 0.86038
# Test Accuracy : 0.71110
# Elapsed time of an epoch: 36.06416
# =====================================
# Epoch : 08 , Cost : 0.16342
# Train Accuracy : 0.92714
# Test Accuracy : 0.75210
# Elapsed time of an epoch: 39.02986
# =====================================
# Epoch : 09 , Cost : 0.13162
# Train Accuracy : 0.94320
# Test Accuracy : 0.75530
# Elapsed time of an epoch: 36.09302
# =====================================
# Epoch : 10 , Cost : 0.10617
# Train Accuracy : 0.89874
# Test Accuracy : 0.71590
# Elapsed time of an epoch: 35.94565
# =====================================
# Epoch : 11 , Cost : 0.09172
# Train Accuracy : 0.96602
# Test Accuracy : 0.76460
# Elapsed time of an epoch: 35.97874
# ===========Best accuracy=============
# Mon May 21 20:33:23 2018
# Best Accuracy : 0.76460
# Elapsed time to get the best accuracy: 400.02574
# =====================================
# Epoch : 12 , Cost : 0.07610
# Train Accuracy : 0.91076
# Test Accuracy : 0.72230
# Elapsed time of an epoch: 35.95267
# =====================================
# Epoch : 13 , Cost : 0.07290
# Train Accuracy : 0.94798
# Test Accuracy : 0.74320
# Elapsed time of an epoch: 35.97273
# =====================================
# Epoch : 14 , Cost : 0.07416
# Train Accuracy : 0.96024
# Test Accuracy : 0.76230
# Elapsed time of an epoch: 36.33414
# =====================================
# Epoch : 15 , Cost : 0.05666
# Train Accuracy : 0.97870
# Test Accuracy : 0.77180
# Elapsed time of an epoch: 36.56428
# ===========Best accuracy=============
# Mon May 21 20:35:47 2018
# Best Accuracy : 0.77180
# Elapsed time to get the best accuracy: 544.84955
# =====================================
# Epoch : 16 , Cost : 0.05672
# Train Accuracy : 0.96252
# Test Accuracy : 0.75200
# Elapsed time of an epoch: 38.55159
# =====================================
# Epoch : 17 , Cost : 0.05099
# Train Accuracy : 0.95380
# Test Accuracy : 0.74270
# Elapsed time of an epoch: 36.08603
# =====================================
# Epoch : 18 , Cost : 0.04766
# Train Accuracy : 0.97130
# Test Accuracy : 0.76050
# Elapsed time of an epoch: 36.54767
# =====================================
# Epoch : 19 , Cost : 0.04788
# Train Accuracy : 0.96782
# Test Accuracy : 0.75730
# Elapsed time of an epoch: 35.80729
# =====================================
# Epoch : 20 , Cost : 0.04979
# Train Accuracy : 0.96160
# Test Accuracy : 0.74940
# Elapsed time of an epoch: 35.94265
# =====================================
# Epoch : 21 , Cost : 0.04141
# Train Accuracy : 0.98640
# Test Accuracy : 0.77370
# Elapsed time of an epoch: 35.87447
# ===========Best accuracy=============
# Mon May 21 20:39:26 2018
# Best Accuracy : 0.77370
# Elapsed time to get the best accuracy: 763.66024
# =====================================
# Epoch : 22 , Cost : 0.04098
# Train Accuracy : 0.98178
# Test Accuracy : 0.77140
# Elapsed time of an epoch: 35.80728
# =====================================
# Epoch : 23 , Cost : 0.04361
# Train Accuracy : 0.97116
# Test Accuracy : 0.75480
# Elapsed time of an epoch: 36.06397
# =====================================
# Epoch : 24 , Cost : 0.03750
# Train Accuracy : 0.96588
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-ea510f2daa6d> in <module>()
#      22     train_accuracy, _, _ = get_accuracy(sess, logits, trX, trY, BATCH_SIZE)
#      23     print('Train Accuracy : {:.5f}'.format(train_accuracy))
# ---> 24     test_accuracy, _, _ = get_accuracy(sess, logits, teX, teY, BATCH_SIZE)
#      25     print('Test Accuracy : {:.5f}'.format(test_accuracy))
#      26     print('Elapsed time of an epoch: {:.5f}'.format(time.time() - epoch_start))
#
# <ipython-input-9-3f6645b8cfc1> in get_accuracy(sess, logits, img, label, batch_size)
#      10             idxs_i = idxs[i * batch_size : (i + 1) * batch_size]
#      11             feed_dict = {X: img[idxs_i], training: False}
# ---> 12             logit = np.concatenate((logit, sess.run(logits, feed_dict=feed_dict)), axis=0)
#      13
#      14     correct_pred = np.equal(np.argmax(logit, 1), label).astype(np.float32)
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
print('Final Test Accuracy : {:.5f}'.format(max_accuracy))
# Out:
# Final Test Accuracy : 0.77370
